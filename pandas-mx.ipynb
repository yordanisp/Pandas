# %%
## Pandas mx ##

# %%
import pandas as pd
import numpy as np

# %%
data={'Name':
      ['Carlos','Brayi','Eugenio','Marc','Steven'],'Notes':
      ['100', '85', '93', '68', '78'], 'Sports':
      ['Football','Basketball','Hockey','Poker','Volleyball'],'Car':
      ['Volvo','Mercedes','Toyota','GMC','Chrysler']}

# %%
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#       Name Notes      Sports       Car
# 0   Carlos   100    Football     Volvo
# 1    Brayi    85  Basketball  Mercedes
# 2  Eugenio    93      Hockey    Toyota
# 3     Marc    68       Poker       GMC
# 4   Steven    78  Volleyball  Chrysler

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Name Notes      Sports       Car
# 0   Carlos   100    Football     Volvo
# 1    Brayi    85  Basketball  Mercedes
# 2  Eugenio    93      Hockey    Toyota
# 3     Marc    68       Poker       GMC
# 4   Steven    78  Volleyball  Chrysler>

# %%
df.iloc[0:]
# Out:
#       Name Notes      Sports       Car
# 0   Carlos   100    Football     Volvo
# 1    Brayi    85  Basketball  Mercedes
# 2  Eugenio    93      Hockey    Toyota
# 3     Marc    68       Poker       GMC
# 4   Steven    78  Volleyball  Chrysler

# %%
print('\n'*4)

# %% [markdown]
# ## Fucking Pokemons ##

# %%
import pandas as pd
import os

# %%
path = ("/Users/yordanis/Desktop/Pandas")

# %%
# !ls {path}
# Out:
# Pandas test.ipynb Pokemon.ipynb     pandas-mx.ipynb   pokemon_data.csv

# %%
pokemon = pd.read_csv("pokemon_data.csv")
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df = pd.DataFrame(pokemon) 
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-140-35cd201b82e1> in <module>
# ----> 1 df = pd.DataFrame(pokemon, ignore_index=True)
#       2 df.head()
#
# TypeError: __init__() got an unexpected keyword argument 'ignore_index'

# %%
df.dropna()
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 6      6              Charizard     Fire  Flying  78      84       78
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.iloc[0:]
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Length: 800, dtype: bool

# %%
df.shape
# Out:
# (800, 12)

# %%
df[:]
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.Name
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df.Speed[2:50]
# Out:
# 2      80
# 3      80
# 4      65
# 5      80
# 6     100
# 7     100
# 8     100
# 9      43
# 10     58
# 11     78
# 12     78
# 13     45
# 14     30
# 15     70
# 16     50
# 17     35
# 18     75
# 19    145
# 20     56
# 21     71
# 22    101
# 23    121
# 24     72
# 25     97
# 26     70
# 27    100
# 28     55
# 29     80
# 30     90
# 31    110
# 32     40
# 33     65
# 34     41
# 35     56
# 36     76
# 37     50
# 38     65
# 39     85
# 40     35
# 41     60
# 42     65
# 43    100
# 44     20
# 45     45
# 46     55
# 47     90
# 48     30
# 49     40
# Name: Speed, dtype: int64

# %%
only80 = df.HP[80]

# %%
only80
# Out:
# 40
